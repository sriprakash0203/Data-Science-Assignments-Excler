# %% [markdown]
# # Topics: Descriptive Statistics and Probability

# %% [markdown]
# # Q1

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
measure=pd.Series([24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00])

# %%
company=['Allied Signal','Bankers Trust','General Mills','ITT Industries','J.P.Morgan & Co.','Lehman Brothers', 
      'MarrioX','MCI','Merrill Lynch','MicrosoZ','Morgan Stanley','Sun Microsystems','Travelers','US Airways','Warner-Lambert']

# %%
plt.figure(figsize=(10,8))
plt.pie(measure,autopct='%1.2f%%',labels=company)
# Out:
# ([<matplotlib.patches.Wedge at 0x1b48a8d4be0>,
# ...
#  [Text(1.087229608003385, 0.16712803319852174, 'Allied Signal'),
#   Text(0.9828289461480074, 0.4940113992749534, 'Bankers Trust'),
#   Text(0.7770213716923852, 0.7786127329637529, 'General Mills'),
#   Text(0.500589114389161, 0.9794950426393569, 'ITT Industries'),
#   Text(0.14701343081593748, 1.09013166689154, 'J.P.Morgan & Co.'),
#   Text(-0.25102787165672724, 1.0709738594622624, 'Lehman Brothers'),
#   Text(-0.5940932351165659, 0.9257716932315078, 'MarrioX'),
#   Text(-0.852379310544051, 0.6953053364935786, 'MCI'),
#   Text(-1.057980932673138, 0.30112513362400867, 'Merrill Lynch'),
#   Text(-1.0815202792052954, -0.20078318073907453, 'MicrosoZ'),
#   Text(-0.6253838571430779, -0.9049281911979793, 'Morgan Stanley'),
#   Text(0.14694509767976283, -1.0901408800094992, 'Sun Microsystems'),
#   Text(0.57095205164786, -0.9402200565394782, 'Travelers'),
#   Text(0.902381559110251, -0.6290528767740856, 'US Airways'),
# ...

# %%
fig=plt.figure(figsize=(10,7))
plt.boxplot(measure)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b48b024fa0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b48b03b580>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b48b024b50>],
#  'medians': [<matplotlib.lines.Line2D at 0x1b48b03bca0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1b48b045070>],
#  'means': []}

# %%
measure.mean()
# Out:
# 33.27133333333333

# %%
measure.var()
# Out:
# 287.1466123809524

# %%
measure.std()
# Out:
# 16.945400921222028

# %% [markdown]
# # Topics: Normal distribution, Functions of Random Variables

# %% [markdown]
# # Q1

# %%
from scipy import stats
stats.norm.cdf(50,loc=45,scale=8)
# Out:
# 0.7340144709512995

# %% [markdown]
# # Q2

# %%
#A
from scipy import stats
400*(1-stats.norm.cdf(44,loc=38,scale=6))
# Out:
# 63.46210157258283

# %%
from scipy import stats
400*(stats.norm.cdf(44,loc=38,scale=6)-stats.norm.cdf(38,loc=38,scale=6))
# Out:
# 136.53789842741716

# %%
#B
from scipy import stats
400*stats.norm.cdf(30,loc=38,scale=6)
# Out:
# 36.484487890347154

# %% [markdown]
# # Q5

# %%
import numpy as np
from scipy import stats
from scipy.stats import norm

# %%
Mean = 5+7 
print('Mean Proﬁt is Rs', Mean*45,'Million')
# Out:
# Mean Proﬁt is Rs 540 Million

# %%
SD = np.sqrt((9)+(16)) 
print('Standard Deviationis Rs', SD*45, 'Million')
# Out:
# Standard Deviationis Rs 225.0 Million

# %%
#A
print('Range is Rs',(stats.norm.interval(0.95,540,225)),'in Millions')
# Out:
# Range is Rs (99.00810347848784, 980.9918965215122) in Millions

# %%
#B
X= 540+(-1.645)*(225) 
print('5th percentile of proﬁt (in Million Rupees) is',np.round(X,))
# Out:
# 5th percentile of proﬁt (in Million Rupees) is 170.0

# %%
#C
# Probability of Division 1 making a loss P(X<0) 
stats.norm.cdf(0,5,3)
# Out:
# 0.0477903522728147

# %%
# Probability of Division 2 making a loss P(X<0) 
stats.norm.cdf(0,7,4)
# Out:
# 0.040059156863817086

# %% [markdown]
# # Topics: Sampling Distributions and Central Limit Theorem

# %% [markdown]
# # Q3

# %%
import numpy as np
from scipy import stats
stats.norm.cdf(1.25)-stats.norm.cdf(-1.25)
# Out:
# 0.7887004526662893

# %%
stats.norm.interval(0.7887,loc=50,scale=40/(100**0.5))
# Out:
# (45.00000495667348, 54.99999504332652)
